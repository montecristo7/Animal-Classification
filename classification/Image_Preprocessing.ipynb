# %%
import os
import shutil
import re

import torch
import torch.nn as nn
import torch.optim as optim
from torch.optim import lr_scheduler
import torchvision
from torchvision import datasets, models, transforms
import matplotlib.pyplot as plt
import numpy as np
import time
import copy
import pathlib
from skimage import io

from sklearn.model_selection import train_test_split
from collections import Counter

# %%
from classification_dataload import Classification_Dataset
base_dir = 'images'

# %%
dataloader = Classification_Dataset(set_name='train', root_dir=base_dir)

# %%
len(dataloader)
# Out:
# 1164

# %%
plt.imshow(torchvision.utils.make_grid(dataloader[10][0]).numpy().transpose([1,2,0]))
plt.show()
