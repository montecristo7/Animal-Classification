# %%
import os
import shutil
import re

import torch
import torch.nn as nn
import torch.optim as optim
from torch.optim import lr_scheduler
import torchvision
from torchvision import datasets, models, transforms
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np
import time
import copy
import pathlib
from skimage import io

from sklearn.model_selection import train_test_split
from collections import Counter

# %%
from classification_dataload import ClassificationDataset
base_dir = 'image'

# %%
dataloader = ClassificationDataset(set_name='train', root_dir=base_dir)

# %%
plt.figure(figsize=(15, 8))
plt.imshow(torchvision.utils.make_grid(dataloader[10][0]).numpy().transpose([1,2,0]))
plt.show()

# %%
dataloader.get_image_path(10)
# Out:
# WindowsPath('image/train/train_0014_brazilAMLD_SSAMLD2_2_Ghost_01_2019_03_21_20_22_13.jpg')

# %%
plt.figure(figsize=(15, 10))
plt.imshow(mpimg.imread(dataloader.get_image_path(10)))
plt.show()
