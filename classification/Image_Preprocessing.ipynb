# %%
import os
import shutil
import re

import torch
import torch.nn as nn
import torch.optim as optim
from torch.optim import lr_scheduler
import torchvision
from torchvision import datasets, models, transforms
import matplotlib.pyplot as plt
import numpy as np
import time
import copy
import pathlib

# %%
base_dir = 'images'

# %%
{x: datasets.ImageFolder(os.path.join(data_dir, x),
  chosen_transforms[x])
                  for x in ['train', 'val']}

# %%
image_folder = datasets.ImageFolder(base_dir, transforms.Compose([
        transforms.Resize(size=(1440, 1920)),
#         transforms.RandomRotation(degrees=15),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
]))

# %%
dataloaders = torch.utils.data.DataLoader(image_folder, batch_size=4,
  shuffle=True, num_workers=1)

# %%
it = iter(dataloaders)

# %%
inputs, classes = next(it)

# %%
plt.imshow(torchvision.utils.make_grid(inputs).numpy().transpose([1,2,0]))
plt.show()

# %%
image_folder
# Out:
# Dataset ImageFolder
#     Number of datapoints: 1
#     Root location: images
#     StandardTransform
# Transform: Compose(
#                Resize(size=(1440, 1920), interpolation=PIL.Image.BILINEAR)
#                RandomHorizontalFlip(p=0.5)
#                ToTensor()
#            )

# %%
classes.clas
# Out:
# tensor([0])

# %%
out = torchvision.utils.make_grid(inputs)

# %%
out.shape
# Out:
# torch.Size([3, 1440, 1920])
