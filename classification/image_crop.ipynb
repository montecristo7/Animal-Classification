# %%
import classification_dataload
import matplotlib.pyplot as plt
import numpy as np
from torchvision.transforms.functional import crop, to_pil_image

# %%
train_image = classification_dataload.ClassificationDataset(set_name="train", root_dir='image')

# %%
plt.imshow(train_image[0][0].numpy().transpose([1,2,0]))

# %%
idx = -19
to_pil_image(train_image[idx][0])
# Out:
# <PIL.Image.Image image mode=RGB size=450x258 at 0x25430956C48>
