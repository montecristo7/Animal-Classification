# %% [markdown]
# # Dataset Creation - Classification
# Sep 15 2020: Created

# %%
# import libraries
import os
import shutil
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split

# %%
# set directories
os.chdir("../") # change current working directory to root directory of project
brazil_amld_interim = "./data/interim/brazil_amld"
image_classification = "./data/processed/image_classification"
dataset = "dataset01"

# %% [markdown]
# ## Extract Relevant Info for Dataset

# %%
# read csv
df_brazil_amld = pd.read_csv(brazil_amld_interim + "/brazil_amld.csv", dtype="str")

# %%
# extract only images
df_brazil_amld_image = df_brazil_amld[(df_brazil_amld.data_type == "image") & 
                                      (df_brazil_amld.species_binary != "Exclude")].reset_index(drop=True)

# %%
# keep selected columns
df_imgclass_dataset01 = df_brazil_amld_image.iloc[:, np.r_[:10, 12:20]]

# %%
# generate ds_id
df_imgclass_dataset01.index.rename("ds_id", inplace=True)
df_imgclass_dataset01 = df_imgclass_dataset01.reset_index()
df_imgclass_dataset01.ds_id = df_imgclass_dataset01.ds_id.astype("str").str.zfill(4)

# %%
df_imgclass_dataset01
# Out:
#      ds_id file_id   cam_trap               species num_animal  year month  \
# 0     0000    0000  SSAMLD2_2         Guerlinguetus         01  2019    04
# 1     0001    0002  SSAMLD2_2         Guerlinguetus         01  2019    04
# 2     0002    0003  SSAMLD2_2         Guerlinguetus         01  2019    04
# 3     0003    0004  SSAMLD2_2         Guerlinguetus         01  2019    04
# 4     0004    0006  SSAMLD2_2         Guerlinguetus         01  2019    03
# ...    ...     ...        ...                   ...        ...   ...   ...
# 1392  1392    1965       CT03  CanisLupusFamiliaris         01  2018    08
# 1393  1393    1968       CT03  CanisLupusFamiliaris         01  2018    08
# 1394  1394    1970       CT03                 Ghost         01  2018    08
# 1395  1395    1972       CT03                 Ghost         01  2018    08
# 1396  1396    1976       CT03        CerdocyonThous         01  2018    08
#
#      day hour minute second file_type data_type image_id num_animal_new  \
# 0     11   08     48     26       jpg     image     0000             01
# 1     11   08     48     24       jpg     image     0001             01
# 2     11   08     48     20       jpg     image     0002             01
# 3     11   08     48     22       jpg     image     0003             01
# 4     27   07     26     16       jpg     image     0004             01
# ...   ..  ...    ...    ...       ...       ...      ...            ...
# 1392  16   13     30     21       jpg     image     1447             01
# 1393  16   13     29     57       jpg     image     1448             01
# 1394  15   20     44     18       jpg     image     1449             01
# 1395  19   15     30     41       jpg     image     1450             01
# 1396  13   18     59     54       jpg     image     1451             01
#
#                                           file_path_new  \
# 0        ./data/interim/brazil_amld/image/Guerlinguetus
# 1        ./data/interim/brazil_amld/image/Guerlinguetus
# 2        ./data/interim/brazil_amld/image/Guerlinguetus
# 3        ./data/interim/brazil_amld/image/Guerlinguetus
# 4        ./data/interim/brazil_amld/image/Guerlinguetus
# ...                                                 ...
# 1392  ./data/interim/brazil_amld/image/CanisLupusFam...
# 1393  ./data/interim/brazil_amld/image/CanisLupusFam...
# 1394             ./data/interim/brazil_amld/image/Ghost
# 1395             ./data/interim/brazil_amld/image/Ghost
# 1396    ./data/interim/brazil_amld/image/CerdocyonThous
#
#                                           file_name_new species_binary  \
# 0     0000_SSAMLD2_2_Guerlinguetus_01_2019_04_11_08_...         Animal
# 1     0001_SSAMLD2_2_Guerlinguetus_01_2019_04_11_08_...         Animal
# 2     0002_SSAMLD2_2_Guerlinguetus_01_2019_04_11_08_...         Animal
# 3     0003_SSAMLD2_2_Guerlinguetus_01_2019_04_11_08_...         Animal
# 4     0004_SSAMLD2_2_Guerlinguetus_01_2019_03_27_07_...         Animal
# ...                                                 ...            ...
# 1392  1447_CT03_CanisLupusFamiliaris_01_2018_08_16_1...         Animal
# 1393  1448_CT03_CanisLupusFamiliaris_01_2018_08_16_1...         Animal
# 1394         1449_CT03_Ghost_01_2018_08_15_20_44_18.jpg          Ghost
# 1395         1450_CT03_Ghost_01_2018_08_19_15_30_41.jpg          Ghost
# 1396  1451_CT03_CerdocyonThous_01_2018_08_13_18_59_5...         Animal
#
#      species_category
# 0             Rodents
# 1             Rodents
# 2             Rodents
# 3             Rodents
# 4             Rodents
# ...               ...
# 1392          Canines
# 1393          Canines
# 1394            Ghost
# 1395            Ghost
# 1396          Canines
#
# [1397 rows x 19 columns]

# %% [markdown]
# ## Train-val-test split

# %%
# train, val, test split
df_train_val, df_test = train_test_split(df_imgclass_dataset01, test_size=0.2,
                                         stratify=df_imgclass_dataset01.species_binary, random_state=0)
df_train, df_val = train_test_split(df_train_val, test_size=0.125,
                                         stratify=df_train_val.species_binary, random_state=0)

# %%
# same split info into df
df_train = df_train.assign(split = "train")
df_val = df_val.assign(split = "val")
df_test = df_test.assign(split = "test")
# append splits back together
df_imgclass_dataset01_split = df_train.append(df_val).append(df_test)

# %%
# generate file path for dataset
df_imgclass_dataset01_split['label'] = df_imgclass_dataset01_split.species_binary.replace({"Ghost":0, "Animal":1})
df_imgclass_dataset01_split['file_path_ds'] = "/".join((image_classification, dataset)) + "/" + \
df_imgclass_dataset01_split.apply(lambda x:'%s/%s' % (x['split'],x['label']),axis=1)

# %%
# export df to csv
df_imgclass_dataset01_split.to_csv(image_classification + dataset + f"/{dataset}.csv", index=False)

# %% [markdown]
# ## Create Dataset

# %%
# convert df into dict
dataset01_dict = df_imgclass_dataset01_split.to_dict('index')

# %%
# copy all data from raw data directory to interim data directory with renamed file name
for k, v in dataset01_dict.items():
    os.makedirs(v['file_path_ds'], exist_ok=True)
    shutil.copyfile(v['file_path_new'] + '/' + v['file_name_new'], v['file_path_ds'] + "/" + v['file_name_new'])
